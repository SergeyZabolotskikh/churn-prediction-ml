# %% [markdown]
# # Table of Contents
#
# 1. [Stage 1: Imports and Database Details](#Stage-1:-Imports-and-Database-Details)
# 2. [Stage 2: Fetch Data](#Stage-2:-Fetch-Data)
# 3. [Stage 3: ETL and Data Cleaning](#Stage-3:-ETL-and-Data-Cleaning)
# 4. [Stage 4: Prediction](#Stage-4:-Prediction)
# 5. [Stage 5: Data export](#Stage-5:-Data-export)

# %% [markdown]
# ## Stage 1: Imports and Database Details

# %%
# ===============================
# Environment setup
# ===============================
import sys
import subprocess

def install_if_missing(packages):
    for package in packages:
        try:
            __import__(package)
        except ImportError:
            print(f"Installing missing package: {package}")
            subprocess.check_call([sys.executable, "-m", "pip", "install", package])

required_packages = [
    "pandas", "pymongo", "joblib", "json"
]

install_if_missing(required_packages)

mongo_db_host_port = "mongodb://localhost:27017/"
mongo_db_database_name = "Tech"
mongo_db_collection_name = "Customers"

# %% [markdown]
# ## Stage 2: Fetch Data

# %%
# ===============================
# Connect to MongoDB and Load the Data
# ===============================
from pymongo import MongoClient
import pandas as pd

# MongoDB connection string (replace with your actual details)
client = MongoClient(mongo_db_host_port)
mongoDB = client[mongo_db_database_name]
customersCollection = mongoDB[mongo_db_collection_name]

# Get all documents, excluding the _id field
cursor = customersCollection.find({}, {"_id": 0})

# Load data from MongoDB into a DataFrame
dataForPrediction = pd.DataFrame(list(cursor))

# Drop MongoDB’s default _id field (optional)
if '_id' in dataForPrediction.columns:
    dataForPrediction.drop(columns=['_id'], inplace=True)
dataForPredictionOriginal = dataForPrediction.copy(deep=True)
dataForPrediction.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents     tenure  \
# 0     id7044    Male              0     Yes         No   3.880000
# 1     id7045    Male              0      No        Yes  29.779905
# 2     id7046  Female              0     Yes        Yes  34.546357
# 3     id7047    Male              0      No         No   1.790000
# 4     id7048  Female              0      No        Yes   5.580000
#
#          Contract PaperlessBilling            PaymentMethod  MonthlyCharges  \
# 0  Month-to-month             [No]         Electronic check       74.820000
# 1  Month-to-month            [Yes]  Credit card (automatic)       40.301502
# 2  Month-to-month            [Yes]             Mailed check       59.778062
# 3  Month-to-month            [Yes]         Electronic check      100.460000
# 4  Month-to-month            [Yes]         Electronic check       74.880000
#
#   TotalCharges                                           Services
# 0       184.82  {'PhoneService': 'Yes', 'MultipleLines': 'No',...
# 1       1359.7  {'PhoneService': 'No', 'MultipleLines': 'Yes',...
# 2      1752.55  {'PhoneService': 'Yes', 'MultipleLines': 'No',...
# 3       493.84  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...
# 4        74.66  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...

# %% [raw]
# We can see that the raw data is in a slightly different format, we need to normalize it, change that format to the same as we use in Part A

# %%
columns = dataForPrediction.columns.tolist()
columns
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Services']

# %% [raw]
# We have to do an ETL process here and transform the data into the same format that was used to train the ML models

# %% [markdown]
# ## Stage 3: ETL and Data Cleaning

# %% [raw]
# The original data frame looks like:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']
#
# We need to transform the 'Services' column into 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'

# %%
sample_rows = dataForPrediction['Services'].sample(5, random_state=1)
for i, row in enumerate(sample_rows):
     print(f"\n", row)
# Out:
#  {'PhoneService': 'No', 'MultipleLines': 'Yes', 'InternetService': 'No', 'OnlineSecurity': 'Yes', 'OnlineBackup': 'No', 'DeviceProtection': 'No internet service', 'TechSupport': 'Yes', 'StreamingTV': 'Yes', 'StreamingMovies': 'Yes'}
#
#  {'PhoneService': 'Yes', 'MultipleLines': 'No', 'InternetService': 'DSL', 'OnlineSecurity': 'No', 'OnlineBackup': 'No', 'DeviceProtection': 'No', 'TechSupport': 'Yes', 'StreamingTV': 'No', 'StreamingMovies': 'No'}
#
#  {'PhoneService': 'No', 'MultipleLines': 'No', 'InternetService': 'DSL', 'OnlineSecurity': 'No internet service', 'OnlineBackup': 'No', 'DeviceProtection': 'Yes', 'TechSupport': 'No', 'StreamingTV': 'No internet service', 'StreamingMovies': 'No internet service'}
#
#  {'PhoneService': 'Yes', 'MultipleLines': 'No', 'InternetService': 'Fiber optic', 'OnlineSecurity': 'Yes', 'OnlineBackup': 'Yes', 'DeviceProtection': 'No internet service', 'TechSupport': 'No', 'StreamingTV': 'No', 'StreamingMovies': 'No internet service'}
#
#  {'PhoneService': 'Yes', 'MultipleLines': 'No', 'InternetService': 'DSL', 'OnlineSecurity': 'No internet service', 'OnlineBackup': 'Yes', 'DeviceProtection': 'No', 'TechSupport': 'No', 'StreamingTV': 'Yes', 'StreamingMovies': 'No internet service'}

# %%
dataForPrediction['Services'] = dataForPrediction['Services'].apply(lambda x: json.loads(x) if isinstance(x, str) else x)
services_df = dataForPrediction['Services'].apply(pd.Series)
dataForPrediction = pd.concat([dataForPrediction.drop(columns=['Services']), services_df], axis=1)
dataForPrediction.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents     tenure  \
# 0     id7044    Male              0     Yes         No   3.880000
# 1     id7045    Male              0      No        Yes  29.779905
# 2     id7046  Female              0     Yes        Yes  34.546357
# 3     id7047    Male              0      No         No   1.790000
# 4     id7048  Female              0      No        Yes   5.580000
#
#          Contract PaperlessBilling            PaymentMethod  MonthlyCharges  \
# 0  Month-to-month             [No]         Electronic check       74.820000
# 1  Month-to-month            [Yes]  Credit card (automatic)       40.301502
# 2  Month-to-month            [Yes]             Mailed check       59.778062
# 3  Month-to-month            [Yes]         Electronic check      100.460000
# 4  Month-to-month            [Yes]         Electronic check       74.880000
#
#   TotalCharges PhoneService MultipleLines InternetService  \
# 0       184.82          Yes            No             DSL
# 1       1359.7           No           Yes             DSL
# 2      1752.55          Yes            No             DSL
# 3       493.84          Yes           Yes             DSL
# 4        74.66          Yes           Yes             DSL
#
#         OnlineSecurity OnlineBackup     DeviceProtection          TechSupport  \
# 0  No internet service          Yes  No internet service                  Yes
# 1  No internet service          Yes                  Yes  No internet service
# 2                  Yes           No                  Yes                   No
# 3                  Yes           No                  Yes  No internet service
# 4  No internet service           No                   No                  Yes
#
#            StreamingTV      StreamingMovies
# 0                   No                  Yes
# 1                  Yes                  Yes
# 2  No internet service  No internet service
# 3                   No                  Yes
# 4                   No                  Yes

# %% [raw]
# Additionally, the 'PaperlessBilling' column values appear differently; they need to be converted.

# %%
dataForPrediction['PaperlessBilling'] = dataForPrediction['PaperlessBilling'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)
dataForPrediction.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents     tenure  \
# 0     id7044    Male              0     Yes         No   3.880000
# 1     id7045    Male              0      No        Yes  29.779905
# 2     id7046  Female              0     Yes        Yes  34.546357
# 3     id7047    Male              0      No         No   1.790000
# 4     id7048  Female              0      No        Yes   5.580000
#
#          Contract PaperlessBilling            PaymentMethod  MonthlyCharges  \
# 0  Month-to-month               No         Electronic check       74.820000
# 1  Month-to-month              Yes  Credit card (automatic)       40.301502
# 2  Month-to-month              Yes             Mailed check       59.778062
# 3  Month-to-month              Yes         Electronic check      100.460000
# 4  Month-to-month              Yes         Electronic check       74.880000
#
#   TotalCharges PhoneService MultipleLines InternetService  \
# 0       184.82          Yes            No             DSL
# 1       1359.7           No           Yes             DSL
# 2      1752.55          Yes            No             DSL
# 3       493.84          Yes           Yes             DSL
# 4        74.66          Yes           Yes             DSL
#
#         OnlineSecurity OnlineBackup     DeviceProtection          TechSupport  \
# 0  No internet service          Yes  No internet service                  Yes
# 1  No internet service          Yes                  Yes  No internet service
# 2                  Yes           No                  Yes                   No
# 3                  Yes           No                  Yes  No internet service
# 4  No internet service           No                   No                  Yes
#
#            StreamingTV      StreamingMovies
# 0                   No                  Yes
# 1                  Yes                  Yes
# 2  No internet service  No internet service
# 3                   No                  Yes
# 4                   No                  Yes

# %% [raw]
# Let's drop rows where we don't have a value, and compare data types of the columns.
# Also, do a simple check for values and column data types.

# %%
dataForPrediction = dataForPrediction.replace(r'^\s*$', pd.NA, regex=True)
dataForPrediction = dataForPrediction.dropna()
customerInfo=pd.read_csv("churn.csv")
commonColumns = dataForPrediction.columns.intersection(customerInfo.columns)
for column in commonColumns:
    dtype_pred = dataForPrediction[column].dtype
    dtype_info = customerInfo[column].dtype
    if dtype_pred != dtype_info:
        print(f"Column '{column}' type mismatch: dataForPrediction={dtype_pred}, customerInfo={dtype_info}")
# Out:
# Column 'tenure' type mismatch: dataForPrediction=float64, customerInfo=int64

# %%
dataForPrediction['tenure'] = dataForPrediction['tenure'].astype('int64')
dataForPrediction.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     id7044    Male              0     Yes         No       3
# 1     id7045    Male              0      No        Yes      29
# 2     id7046  Female              0     Yes        Yes      34
# 3     id7047    Male              0      No         No       1
# 4     id7048  Female              0      No        Yes       5
#
#          Contract PaperlessBilling            PaymentMethod  MonthlyCharges  \
# 0  Month-to-month               No         Electronic check       74.820000
# 1  Month-to-month              Yes  Credit card (automatic)       40.301502
# 2  Month-to-month              Yes             Mailed check       59.778062
# 3  Month-to-month              Yes         Electronic check      100.460000
# 4  Month-to-month              Yes         Electronic check       74.880000
#
#   TotalCharges PhoneService MultipleLines InternetService  \
# 0       184.82          Yes            No             DSL
# 1       1359.7           No           Yes             DSL
# 2      1752.55          Yes            No             DSL
# 3       493.84          Yes           Yes             DSL
# 4        74.66          Yes           Yes             DSL
#
#         OnlineSecurity OnlineBackup     DeviceProtection          TechSupport  \
# 0  No internet service          Yes  No internet service                  Yes
# 1  No internet service          Yes                  Yes  No internet service
# 2                  Yes           No                  Yes                   No
# 3                  Yes           No                  Yes  No internet service
# 4  No internet service           No                   No                  Yes
#
#            StreamingTV      StreamingMovies
# 0                   No                  Yes
# 1                  Yes                  Yes
# 2  No internet service  No internet service
# 3                   No                  Yes
# 4                   No                  Yes

# %%
sampleOfDataForPrediction = dataForPrediction.sample(n=min(500, len(dataForPrediction)), random_state=42)
for column in sampleOfDataForPrediction.columns:
    if sampleOfDataForPrediction[column].nunique() <= 10:
        print(f"\nColumn: {column}")
        values_pred = set(sampleOfDataForPrediction[column].unique())
        if column in customerInfo.columns:
            values_info = set(customerInfo[column].unique())
            print("Values in dataForPrediction:", values_pred)
            print("Values in customerInfo:", values_info)
            only_in_pred = values_pred - values_info
            only_in_info = values_info - values_pred
            if only_in_pred or only_in_info:
                print("Differences:")
                if only_in_pred:
                    print(" - Values only in dataForPrediction:", only_in_pred)
                if only_in_info:
                    print(" - Values only in customerInfo:", only_in_info)
# Out:
# Column: gender
# Values in dataForPrediction: {'Male', 'Female'}
# Values in customerInfo: {'Male', 'Female'}
#
# Column: SeniorCitizen
# Values in dataForPrediction: {np.int64(0), np.int64(1)}
# Values in customerInfo: {np.int64(0), np.int64(1)}
#
# Column: Partner
# Values in dataForPrediction: {'No', 'Yes'}
# Values in customerInfo: {'No', 'Yes'}
#
# Column: Dependents
# Values in dataForPrediction: {'No', 'Yes'}
# Values in customerInfo: {'No', 'Yes'}
#
# Column: Contract
# Values in dataForPrediction: {'Month-to-month', 'One year', 'Two year'}
# Values in customerInfo: {'Month-to-month', 'One year', 'Two year'}
#
# Column: PaperlessBilling
# Values in dataForPrediction: {'No', 'Yes'}
# Values in customerInfo: {'No', 'Yes'}
#
# Column: PaymentMethod
# Values in dataForPrediction: {'Bank transfer (automatic)', 'Electronic check', 'Mailed check', 'Credit card (automatic)'}
# Values in customerInfo: {'Bank transfer (automatic)', 'Electronic check', 'Mailed check', 'Credit card (automatic)'}
#
# Column: PhoneService
# Values in dataForPrediction: {'No', 'Yes'}
# Values in customerInfo: {'No', 'Yes'}
#
# Column: MultipleLines
# Values in dataForPrediction: {'No phone service', 'No', 'Yes'}
# Values in customerInfo: {'No phone service', 'No', 'Yes'}
#
# Column: InternetService
# Values in dataForPrediction: {'DSL', 'No', 'Fiber optic'}
# Values in customerInfo: {'DSL', 'No', 'Fiber optic'}
#
# Column: OnlineSecurity
# Values in dataForPrediction: {'No internet service', 'No', 'Yes'}
# Values in customerInfo: {'No internet service', 'No', 'Yes'}
#
# Column: OnlineBackup
# Values in dataForPrediction: {'No internet service', 'No', 'Yes'}
# Values in customerInfo: {'No internet service', 'No', 'Yes'}
#
# Column: DeviceProtection
# Values in dataForPrediction: {'No internet service', 'No', 'Yes'}
# Values in customerInfo: {'No internet service', 'No', 'Yes'}
#
# Column: TechSupport
# Values in dataForPrediction: {'No internet service', 'No', 'Yes'}
# Values in customerInfo: {'No internet service', 'No', 'Yes'}
#
# Column: StreamingTV
# Values in dataForPrediction: {'No internet service', 'No', 'Yes'}
# Values in customerInfo: {'No internet service', 'No', 'Yes'}
#
# Column: StreamingMovies
# Values in dataForPrediction: {'No internet service', 'No', 'Yes'}
# Values in customerInfo: {'No internet service', 'No', 'Yes'}

# %%
dataForPrediction.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     id7044    Male              0     Yes         No       3
# 1     id7045    Male              0      No        Yes      29
# 2     id7046  Female              0     Yes        Yes      34
# 3     id7047    Male              0      No         No       1
# 4     id7048  Female              0      No        Yes       5
#
#          Contract PaperlessBilling            PaymentMethod  MonthlyCharges  \
# 0  Month-to-month               No         Electronic check       74.820000
# 1  Month-to-month              Yes  Credit card (automatic)       40.301502
# 2  Month-to-month              Yes             Mailed check       59.778062
# 3  Month-to-month              Yes         Electronic check      100.460000
# 4  Month-to-month              Yes         Electronic check       74.880000
#
#   TotalCharges PhoneService MultipleLines InternetService  \
# 0       184.82          Yes            No             DSL
# 1       1359.7           No           Yes             DSL
# 2      1752.55          Yes            No             DSL
# 3       493.84          Yes           Yes             DSL
# 4        74.66          Yes           Yes             DSL
#
#         OnlineSecurity OnlineBackup     DeviceProtection          TechSupport  \
# 0  No internet service          Yes  No internet service                  Yes
# 1  No internet service          Yes                  Yes  No internet service
# 2                  Yes           No                  Yes                   No
# 3                  Yes           No                  Yes  No internet service
# 4  No internet service           No                   No                  Yes
#
#            StreamingTV      StreamingMovies
# 0                   No                  Yes
# 1                  Yes                  Yes
# 2  No internet service  No internet service
# 3                   No                  Yes
# 4                   No                  Yes

# %%
dataForPrediction.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
customerInfo.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
column_mapping = {
    'customerID': 'customer_id',
    'gender': 'gender',
    'SeniorCitizen': 'senior_citizen',
    'Partner': 'has_partner',
    'Dependents': 'has_dependents',
    'tenure': 'tenure_in_months',
    'PhoneService': 'has_phone_srv',
    'MultipleLines': 'has_multiple_lines',
    'InternetService': 'has_internet_srv',
    'OnlineSecurity': 'has_online_security_srv',
    'OnlineBackup': 'has_online__backup_srv',
    'DeviceProtection': 'has_device_protection_srv',
    'TechSupport': 'has_tech_support_srv',
    'StreamingTV': 'has_streaming_tv_srv',
    'StreamingMovies': 'has_streaming_movies_srv',
    'Contract': 'contract_term',
    'PaperlessBilling': 'has_paperless_bill',
    'PaymentMethod': 'payment_method',
    'MonthlyCharges': 'monthly_charges',
    'TotalCharges': 'total_charges'
}
dataForPrediction.rename(columns=column_mapping, inplace=True)

# Binary conversion
dataForPrediction['has_partner'] = (dataForPrediction['has_partner'] == 'Yes').astype(int)
dataForPrediction['has_dependents'] = (dataForPrediction['has_dependents'] == 'Yes').astype(int)
dataForPrediction['has_phone_srv'] = (dataForPrediction['has_phone_srv'] == 'Yes').astype(int)
dataForPrediction['has_multiple_lines_yes'] = (dataForPrediction['has_multiple_lines'] == 'Yes').astype(int)
dataForPrediction.drop(columns=['has_multiple_lines'], inplace=True)

# Gender
dataForPrediction.drop(columns=['gender'], inplace=True)

# Internet service types
dataForPrediction['has_dsl'] = (dataForPrediction['has_internet_srv'] == 'DSL').astype(int)
dataForPrediction['has_fiber'] = (dataForPrediction['has_internet_srv'] == 'Fiber optic').astype(int)
dataForPrediction['no_internet_srv'] = (dataForPrediction['has_internet_srv'] == 'No').astype(int)

# Additional services
additional_srv_columns = [
    'has_online_security_srv', 'has_online__backup_srv',
    'has_device_protection_srv', 'has_tech_support_srv',
    'has_streaming_tv_srv', 'has_streaming_movies_srv'
]
for col in additional_srv_columns:
    dataForPrediction[col + '_yes'] = (dataForPrediction[col] == 'Yes').astype(int)
dataForPrediction.drop(columns=['has_internet_srv'] + additional_srv_columns, inplace=True)

# Contract term
dataForPrediction['month_to_month_contract'] = (dataForPrediction['contract_term'] == 'Month-to-month').astype(int)
dataForPrediction['one_year_contract'] = (dataForPrediction['contract_term'] == 'One year').astype(int)
dataForPrediction['two_years_contract'] = (dataForPrediction['contract_term'] == 'Two year').astype(int)
dataForPrediction['has_paperless_bill'] = (dataForPrediction['has_paperless_bill'] == 'Yes').astype(int)
dataForPrediction.drop(columns=['contract_term'], inplace=True)

# Payment methods
dataForPrediction['electronic_check'] = (dataForPrediction['payment_method'] == 'Electronic check').astype(int)
dataForPrediction['mailed_check'] = (dataForPrediction['payment_method'] == 'Mailed check').astype(int)
dataForPrediction['automatic_bank_transfer'] = (dataForPrediction['payment_method'] == 'Bank transfer (automatic)').astype(int)
dataForPrediction['automatic_credit_card'] = (dataForPrediction['payment_method'] == 'Credit card (automatic)').astype(int)
dataForPrediction.drop(columns=['payment_method'], inplace=True)

# Total charges fix
dataForPrediction['total_charges'] = pd.to_numeric(dataForPrediction['total_charges'], errors='coerce').fillna(0)

dataForPrediction.head()
# Out:
#   customer_id  senior_citizen  has_partner  has_dependents  tenure_in_months  \
# 0      id7044               0            1               0                 3
# 1      id7045               0            0               1                29
# 2      id7046               0            1               1                34
# 3      id7047               0            0               0                 1
# 4      id7048               0            0               1                 5
#
#    has_paperless_bill  monthly_charges  total_charges  has_phone_srv  \
# 0                   0        74.820000         184.82              1
# 1                   1        40.301502        1359.70              0
# 2                   1        59.778062        1752.55              1
# 3                   1       100.460000         493.84              1
# 4                   1        74.880000          74.66              1
#
#    has_multiple_lines_yes  ...  has_tech_support_srv_yes  \
# 0                       0  ...                         1
# 1                       1  ...                         0
# 2                       0  ...                         0
# 3                       1  ...                         0
# 4                       1  ...                         1
#
#    has_streaming_tv_srv_yes  has_streaming_movies_srv_yes  \
# 0                         0                             1
# 1                         1                             1
# 2                         0                             0
# 3                         0                             1
# 4                         0                             1
#
#    month_to_month_contract  one_year_contract  two_years_contract  \
# 0                        1                  0                   0
# 1                        1                  0                   0
# 2                        1                  0                   0
# 3                        1                  0                   0
# 4                        1                  0                   0
#
#    electronic_check  mailed_check  automatic_bank_transfer  \
# 0                 1             0                        0
# 1                 0             0                        0
# 2                 0             1                        0
# 3                 1             0                        0
# 4                 1             0                        0
#
#    automatic_credit_card
# 0                      0
# 1                      1
# 2                      0
# 3                      0
# 4                      0
#
# [5 rows x 26 columns]

# %%
print(dataForPrediction.dtypes)
# Out:
# customer_id                       object
# senior_citizen                     int64
# has_partner                        int64
# has_dependents                     int64
# tenure_in_months                   int64
# has_paperless_bill                 int64
# monthly_charges                  float64
# total_charges                    float64
# has_phone_srv                      int64
# has_multiple_lines_yes             int64
# has_dsl                            int64
# has_fiber                          int64
# no_internet_srv                    int64
# has_online_security_srv_yes        int64
# has_online__backup_srv_yes         int64
# has_device_protection_srv_yes      int64
# has_tech_support_srv_yes           int64
# has_streaming_tv_srv_yes           int64
# has_streaming_movies_srv_yes       int64
# month_to_month_contract            int64
# one_year_contract                  int64
# two_years_contract                 int64
# electronic_check                   int64
# mailed_check                       int64
# automatic_bank_transfer            int64
# automatic_credit_card              int64
# dtype: object

# %% [raw]
# The data is clean and ready for the next stage - prediction

# %% [markdown]
# ## Stage 4: Prediction

# %% [raw]
# Let's use the best model from Part A, it was Random Forest

# %%
# !pip install joblib
import joblib
model = joblib.load("random_forest_best_model.joblib")
customerIdsColumn = dataForPrediction['customer_id']
onlyNeededData = dataForPrediction.drop(columns=['customer_id'])
onlyNeededData = onlyNeededData[model.feature_names_in_]
dataForPrediction['churn'] = model.predict(onlyNeededData)
dataForPrediction['customer_id'] = customerIdsColumn
# Out:
# Requirement already satisfied: joblib in c:\python\python313\lib\site-packages (1.4.2)
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dataForPrediction
# Out:
#       customer_id  senior_citizen  has_partner  has_dependents  \
# 0          id7044               0            1               0
# 1          id7045               0            0               1
# 2          id7046               0            1               1
# 3          id7047               0            0               0
# 4          id7048               0            0               1
# ...           ...             ...          ...             ...
# 24994     id32038               0            0               0
# 24995     id32039               0            0               1
# 24996     id32040               0            0               1
# 24997     id32041               0            1               1
# 24998     id32042               0            0               0
#
#        tenure_in_months  has_paperless_bill  monthly_charges  total_charges  \
# 0                     3                   0        74.820000         184.82
# 1                    29                   1        40.301502        1359.70
# 2                    34                   1        59.778062        1752.55
# 3                     1                   1       100.460000         493.84
# 4                     5                   1        74.880000          74.66
# ...                 ...                 ...              ...            ...
# 24994                10                   1        91.817322         867.30
# 24995                 4                   0        84.500000         476.82
# 24996                 3                   1        90.710000         329.33
# 24997                33                   1        76.120814         238.15
# 24998                 2                   1       100.320000          14.13
#
#        has_phone_srv  has_multiple_lines_yes  ...  has_streaming_tv_srv_yes  \
# 0                  1                       0  ...                         0
# 1                  0                       1  ...                         1
# 2                  1                       0  ...                         0
# 3                  1                       1  ...                         0
# 4                  1                       1  ...                         0
# ...              ...                     ...  ...                       ...
# 24994              1                       1  ...                         1
# 24995              1                       1  ...                         0
# 24996              1                       1  ...                         1
# 24997              1                       1  ...                         0
# 24998              1                       0  ...                         1
#
#        has_streaming_movies_srv_yes  month_to_month_contract  \
# 0                                 1                        1
# 1                                 1                        1
# 2                                 0                        1
# 3                                 1                        1
# 4                                 1                        1
# ...                             ...                      ...
# 24994                             0                        1
# 24995                             0                        1
# 24996                             0                        1
# 24997                             0                        1
# 24998                             0                        1
#
#        one_year_contract  two_years_contract  electronic_check  mailed_check  \
# 0                      0                   0                 1             0
# 1                      0                   0                 0             0
# 2                      0                   0                 0             1
# 3                      0                   0                 1             0
# 4                      0                   0                 1             0
# ...                  ...                 ...               ...           ...
# 24994                  0                   0                 0             0
# 24995                  0                   0                 1             0
# 24996                  0                   0                 1             0
# 24997                  0                   0                 0             1
# 24998                  0                   0                 1             0
#
#        automatic_bank_transfer  automatic_credit_card  churn
# 0                            0                      0      0
# 1                            0                      1      0
# 2                            0                      0      0
# 3                            0                      0      0
# 4                            0                      0      0
# ...                        ...                    ...    ...
# 24994                        0                      1      1
# 24995                        0                      0      0
# 24996                        0                      0      1
# 24997                        0                      0      0
# 24998                        0                      0      1
#
# [24218 rows x 27 columns]

# %% [markdown]
# ## Stage 5. Data export

# %%
churnPredicted = dataForPrediction.set_index("customer_id")["churn"].map({1: "Yes", 0: "No"})
dataForPredictionOriginal["Churn"] = dataForPredictionOriginal["customerID"].map(churnPredicted)
dataForPredictionOriginal
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents     tenure  \
# 0         id7044    Male              0     Yes         No   3.880000
# 1         id7045    Male              0      No        Yes  29.779905
# 2         id7046  Female              0     Yes        Yes  34.546357
# 3         id7047    Male              0      No         No   1.790000
# 4         id7048  Female              0      No        Yes   5.580000
# ...          ...     ...            ...     ...        ...        ...
# 24995    id32039    Male              0      No        Yes   4.400000
# 24996    id32040    Male              0      No        Yes   3.130000
# 24997    id32041    Male              0     Yes        Yes  33.154407
# 24998    id32042  Female              0      No         No   2.480000
# 24999    id32043    Male              0     Yes        Yes  34.873146
#
#              Contract PaperlessBilling            PaymentMethod  \
# 0      Month-to-month             [No]         Electronic check
# 1      Month-to-month            [Yes]  Credit card (automatic)
# 2      Month-to-month            [Yes]             Mailed check
# 3      Month-to-month            [Yes]         Electronic check
# 4      Month-to-month            [Yes]         Electronic check
# ...               ...              ...                      ...
# 24995  Month-to-month             [No]         Electronic check
# 24996  Month-to-month            [Yes]         Electronic check
# 24997  Month-to-month            [Yes]             Mailed check
# 24998  Month-to-month            [Yes]         Electronic check
# 24999  Month-to-month             [No]                      NaN
#
#        MonthlyCharges TotalCharges  \
# 0           74.820000       184.82
# 1           40.301502       1359.7
# 2           59.778062      1752.55
# 3          100.460000       493.84
# 4           74.880000        74.66
# ...               ...          ...
# 24995       84.500000       476.82
# 24996       90.710000       329.33
# 24997       76.120814       238.15
# 24998      100.320000        14.13
# 24999      107.125074      4616.05
#
#                                                 Services Churn
# 0      {'PhoneService': 'Yes', 'MultipleLines': 'No',...    No
# 1      {'PhoneService': 'No', 'MultipleLines': 'Yes',...    No
# 2      {'PhoneService': 'Yes', 'MultipleLines': 'No',...    No
# 3      {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...    No
# 4      {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...    No
# ...                                                  ...   ...
# 24995  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...    No
# 24996  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...   Yes
# 24997  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...    No
# 24998  {'PhoneService': 'Yes', 'MultipleLines': 'No',...   Yes
# 24999  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...   NaN
#
# [25000 rows x 13 columns]

# %%
dataForPredictionOriginal['PaperlessBilling'] = dataForPredictionOriginal['PaperlessBilling'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else x)
dataForPredictionOriginal
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents     tenure  \
# 0         id7044    Male              0     Yes         No   3.880000
# 1         id7045    Male              0      No        Yes  29.779905
# 2         id7046  Female              0     Yes        Yes  34.546357
# 3         id7047    Male              0      No         No   1.790000
# 4         id7048  Female              0      No        Yes   5.580000
# ...          ...     ...            ...     ...        ...        ...
# 24995    id32039    Male              0      No        Yes   4.400000
# 24996    id32040    Male              0      No        Yes   3.130000
# 24997    id32041    Male              0     Yes        Yes  33.154407
# 24998    id32042  Female              0      No         No   2.480000
# 24999    id32043    Male              0     Yes        Yes  34.873146
#
#              Contract PaperlessBilling            PaymentMethod  \
# 0      Month-to-month               No         Electronic check
# 1      Month-to-month              Yes  Credit card (automatic)
# 2      Month-to-month              Yes             Mailed check
# 3      Month-to-month              Yes         Electronic check
# 4      Month-to-month              Yes         Electronic check
# ...               ...              ...                      ...
# 24995  Month-to-month               No         Electronic check
# 24996  Month-to-month              Yes         Electronic check
# 24997  Month-to-month              Yes             Mailed check
# 24998  Month-to-month              Yes         Electronic check
# 24999  Month-to-month               No                      NaN
#
#        MonthlyCharges TotalCharges  \
# 0           74.820000       184.82
# 1           40.301502       1359.7
# 2           59.778062      1752.55
# 3          100.460000       493.84
# 4           74.880000        74.66
# ...               ...          ...
# 24995       84.500000       476.82
# 24996       90.710000       329.33
# 24997       76.120814       238.15
# 24998      100.320000        14.13
# 24999      107.125074      4616.05
#
#                                                 Services Churn
# 0      {'PhoneService': 'Yes', 'MultipleLines': 'No',...    No
# 1      {'PhoneService': 'No', 'MultipleLines': 'Yes',...    No
# 2      {'PhoneService': 'Yes', 'MultipleLines': 'No',...    No
# 3      {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...    No
# 4      {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...    No
# ...                                                  ...   ...
# 24995  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...    No
# 24996  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...   Yes
# 24997  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...    No
# 24998  {'PhoneService': 'Yes', 'MultipleLines': 'No',...   Yes
# 24999  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'...   NaN
#
# [25000 rows x 13 columns]

# %%
dataForPredictionOriginal['Services'] = dataForPredictionOriginal['Services'].apply(lambda x: json.loads(x) if isinstance(x, str) else x)
services_df = dataForPredictionOriginal['Services'].apply(pd.Series)
dataForPredictionOriginal = pd.concat([dataForPredictionOriginal.drop(columns=['Services']), services_df], axis=1)
dataForPredictionOriginal
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents     tenure  \
# 0         id7044    Male              0     Yes         No   3.880000
# 1         id7045    Male              0      No        Yes  29.779905
# 2         id7046  Female              0     Yes        Yes  34.546357
# 3         id7047    Male              0      No         No   1.790000
# 4         id7048  Female              0      No        Yes   5.580000
# ...          ...     ...            ...     ...        ...        ...
# 24995    id32039    Male              0      No        Yes   4.400000
# 24996    id32040    Male              0      No        Yes   3.130000
# 24997    id32041    Male              0     Yes        Yes  33.154407
# 24998    id32042  Female              0      No         No   2.480000
# 24999    id32043    Male              0     Yes        Yes  34.873146
#
#              Contract PaperlessBilling            PaymentMethod  \
# 0      Month-to-month               No         Electronic check
# 1      Month-to-month              Yes  Credit card (automatic)
# 2      Month-to-month              Yes             Mailed check
# 3      Month-to-month              Yes         Electronic check
# 4      Month-to-month              Yes         Electronic check
# ...               ...              ...                      ...
# 24995  Month-to-month               No         Electronic check
# 24996  Month-to-month              Yes         Electronic check
# 24997  Month-to-month              Yes             Mailed check
# 24998  Month-to-month              Yes         Electronic check
# 24999  Month-to-month               No                      NaN
#
#        MonthlyCharges  ... Churn PhoneService MultipleLines InternetService  \
# 0           74.820000  ...    No          Yes            No             DSL
# 1           40.301502  ...    No           No           Yes             DSL
# 2           59.778062  ...    No          Yes            No             DSL
# 3          100.460000  ...    No          Yes           Yes             DSL
# 4           74.880000  ...    No          Yes           Yes             DSL
# ...               ...  ...   ...          ...           ...             ...
# 24995       84.500000  ...    No          Yes           Yes             DSL
# 24996       90.710000  ...   Yes          Yes           Yes     Fiber optic
# 24997       76.120814  ...    No          Yes           Yes     Fiber optic
# 24998      100.320000  ...   Yes          Yes            No     Fiber optic
# 24999      107.125074  ...   NaN          Yes           Yes              No
#
#             OnlineSecurity         OnlineBackup     DeviceProtection  \
# 0      No internet service                  Yes  No internet service
# 1      No internet service                  Yes                  Yes
# 2                      Yes                   No                  Yes
# 3                      Yes                   No                  Yes
# 4      No internet service                   No                   No
# ...                    ...                  ...                  ...
# 24995                  Yes                   No                   No
# 24996  No internet service  No internet service                   No
# 24997                   No                  Yes                   No
# 24998                   No                   No                   No
# 24999  No internet service                   No                   No
#
#                TechSupport          StreamingTV      StreamingMovies
# 0                      Yes                   No                  Yes
# 1      No internet service                  Yes                  Yes
# 2                       No  No internet service  No internet service
# 3      No internet service                   No                  Yes
# 4                      Yes                   No                  Yes
# ...                    ...                  ...                  ...
# 24995                   No                   No  No internet service
# 24996                  Yes                  Yes                   No
# 24997                   No                   No  No internet service
# 24998                  Yes                  Yes                   No
# 24999                   No                  Yes                   No
#
# [25000 rows x 21 columns]

# %%
dataForPredictionOriginal = dataForPredictionOriginal[customerInfo.columns.tolist()]
dataForPredictionOriginal
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents     tenure  \
# 0         id7044    Male              0     Yes         No   3.880000
# 1         id7045    Male              0      No        Yes  29.779905
# 2         id7046  Female              0     Yes        Yes  34.546357
# 3         id7047    Male              0      No         No   1.790000
# 4         id7048  Female              0      No        Yes   5.580000
# ...          ...     ...            ...     ...        ...        ...
# 24995    id32039    Male              0      No        Yes   4.400000
# 24996    id32040    Male              0      No        Yes   3.130000
# 24997    id32041    Male              0     Yes        Yes  33.154407
# 24998    id32042  Female              0      No         No   2.480000
# 24999    id32043    Male              0     Yes        Yes  34.873146
#
#       PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 0              Yes            No             DSL  No internet service  ...
# 1               No           Yes             DSL  No internet service  ...
# 2              Yes            No             DSL                  Yes  ...
# 3              Yes           Yes             DSL                  Yes  ...
# 4              Yes           Yes             DSL  No internet service  ...
# ...            ...           ...             ...                  ...  ...
# 24995          Yes           Yes             DSL                  Yes  ...
# 24996          Yes           Yes     Fiber optic  No internet service  ...
# 24997          Yes           Yes     Fiber optic                   No  ...
# 24998          Yes            No     Fiber optic                   No  ...
# 24999          Yes           Yes              No  No internet service  ...
#
#           DeviceProtection          TechSupport          StreamingTV  \
# 0      No internet service                  Yes                   No
# 1                      Yes  No internet service                  Yes
# 2                      Yes                   No  No internet service
# 3                      Yes  No internet service                   No
# 4                       No                  Yes                   No
# ...                    ...                  ...                  ...
# 24995                   No                   No                   No
# 24996                   No                  Yes                  Yes
# 24997                   No                   No                   No
# 24998                   No                  Yes                  Yes
# 24999                   No                   No                  Yes
#
#            StreamingMovies        Contract PaperlessBilling  \
# 0                      Yes  Month-to-month               No
# 1                      Yes  Month-to-month              Yes
# 2      No internet service  Month-to-month              Yes
# 3                      Yes  Month-to-month              Yes
# 4                      Yes  Month-to-month              Yes
# ...                    ...             ...              ...
# 24995  No internet service  Month-to-month               No
# 24996                   No  Month-to-month              Yes
# 24997  No internet service  Month-to-month              Yes
# 24998                   No  Month-to-month              Yes
# 24999                   No  Month-to-month               No
#
#                  PaymentMethod MonthlyCharges  TotalCharges Churn
# 0             Electronic check      74.820000        184.82    No
# 1      Credit card (automatic)      40.301502        1359.7    No
# 2                 Mailed check      59.778062       1752.55    No
# 3             Electronic check     100.460000        493.84    No
# 4             Electronic check      74.880000         74.66    No
# ...                        ...            ...           ...   ...
# 24995         Electronic check      84.500000        476.82    No
# 24996         Electronic check      90.710000        329.33   Yes
# 24997             Mailed check      76.120814        238.15    No
# 24998         Electronic check     100.320000         14.13   Yes
# 24999                      NaN     107.125074       4616.05   NaN
#
# [25000 rows x 21 columns]

# %%
dataForPredictionOriginal.to_csv("predicted_customers.csv", index=False)
